# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Required Libraries
from music21 import converter, instrument, note, chord, stream
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import os

# %%
def load_midi_files(main_directories):
    midi_files = []
    for directory in main_directories:
        print(directory)
        for root, dirs, files in os.walk(directory):
            # Skip the "versions" subdirectories
            if 'versions' in root:
                continue
            for file in files:
                if file.endswith('.mid') or file.endswith('.midi'):
                    midi_files.append(os.path.join(root, file))
    return midi_files

# Function to Extract Notes from MIDI Files
def get_notes_from_midi(midi_files):
    notes = []
    for file in midi_files[:250]:
        print(file)
        midi = converter.parse(file)
        notes_to_parse = None
        parts = instrument.partitionByInstrument(midi)
        if parts:
            notes_to_parse = parts.parts[0].recurse()
        else:
            notes_to_parse = midi.flat.notes
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))
    return notes

# Prepare Sequences for LSTM
def prepare_sequences(notes, n_vocab, sequence_length=100):
    note_to_int = dict((note, number) for number, note in enumerate(set(notes)))
    network_input = []
    network_output = []
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])
    n_patterns = len(network_input)
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    network_input = network_input / float(n_vocab)
    network_output = to_categorical(network_output)
    return (network_input, network_output, note_to_int)

# Path to MIDI files
data_directory = "/content/drive/MyDrive/Colab Notebooks/data"
pop909_directory = '/content/drive/MyDrive/Colab Notebooks/extracted-POP909'

midi_files = load_midi_files([pop909_directory])
print(midi_files)
# midi_files = [os.path.join(path_to_midi, file) for file in os.listdir(path_to_midi) if file.endswith('.mid')]

# Extract notes from MIDI files
notes = get_notes_from_midi(midi_files)
n_vocab = len(set(notes))

# Prepare sequences
network_input, network_output, note_to_int = prepare_sequences(notes, n_vocab)
int_to_note = dict((number, note) for number, note in enumerate(set(notes)))
# Out:
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909
# ['/content/drive/MyDrive/Colab Notebooks/extracted-POP909/006.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/035.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/030.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/029.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/027.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/028.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/026.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/023.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/024.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/022.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/021.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/025.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/020.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/019.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/018.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/016.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/017.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/011.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/012.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/013.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/014.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/015.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/009.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/010.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/008.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/007.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/005.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/001.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/004.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/003.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/002.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/066.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/064.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/060.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/059.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/057.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/056.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/058.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/055.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/052.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/053.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/051.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/054.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/049.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/050.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/047.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/048.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/046.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/044.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/041.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/043.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/042.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/045.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/040.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/039.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/037.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/036.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/038.mid', '/content/drive/MyDrive/Colab Notebooks/extracted-POP909/033.mid', '/content/drive/MyDrive/Colab Notebooks/extrac ...
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/006.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/035.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/030.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/029.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/027.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/028.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/026.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/023.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/024.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/022.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/021.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/025.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/020.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/019.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/018.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/016.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/017.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/011.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/012.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/013.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/014.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/015.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/009.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/010.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/008.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/007.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/005.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/001.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/004.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/003.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/002.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/066.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/064.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/060.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/059.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/057.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/056.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/058.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/055.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/052.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/053.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/051.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/054.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/049.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/050.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/047.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/048.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/046.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/044.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/041.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/043.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/042.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/045.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/040.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/039.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/037.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/036.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/038.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/033.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/032.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/031.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/034.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/099.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/097.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/098.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/096.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/093.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/092.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/094.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/091.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/095.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/090.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/089.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/088.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/086.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/087.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/082.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/081.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/083.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/084.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/085.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/080.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/079.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/076.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/075.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/078.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/077.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/074.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/071.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/073.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/072.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/070.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/069.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/067.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/061.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/062.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/068.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/065.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/063.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/129.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/126.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/128.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/127.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/121.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/122.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/124.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/123.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/125.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/120.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/119.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/111.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/118.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/117.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/114.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/112.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/115.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/116.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/113.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/110.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/108.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/106.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/107.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/109.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/103.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/102.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/104.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/101.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/105.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/100.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/159.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/158.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/157.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/151.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/152.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/154.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/155.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/153.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/156.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/149.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/150.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/148.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/145.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/146.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/147.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/142.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/143.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/141.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/144.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/140.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/139.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/135.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/138.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/137.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/136.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/132.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/133.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/131.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/134.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/130.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/190.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/189.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/187.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/186.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/185.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/188.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/181.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/182.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/183.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/184.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/180.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/179.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/176.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/177.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/178.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/174.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/171.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/173.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/172.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/175.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/170.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/169.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/168.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/167.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/166.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/163.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/164.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/161.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/162.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/165.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/160.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/220.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/218.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/219.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/217.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/215.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/216.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/211.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/213.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/212.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/214.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/210.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/209.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/208.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/204.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/206.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/207.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/205.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/202.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/201.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/203.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/200.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/199.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/198.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/195.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/196.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/197.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/193.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/192.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/191.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/194.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/254.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/250.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/249.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/246.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/247.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/248.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/243.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/242.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/244.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/241.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/245.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/240.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/239.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/237.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/238.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/236.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/232.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/231.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/235.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/233.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/234.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/230.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/228.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/225.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/226.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/227.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/229.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/221.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/223.mid
# /content/drive/MyDrive/Colab Notebooks/extracted-POP909/222.mid

# %%
epochs = 20
batch_size = 512

# Build LSTM Model
def create_model(network_input, n_vocab):
    model = Sequential()
    model.add(LSTM(512, input_shape=(network_input.shape[1], network_input.shape[2]), recurrent_dropout=0.3, return_sequences=True))
    model.add(LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
    model.add(LSTM(512))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    return model

# Create the model
model = create_model(network_input, n_vocab)

# Train the model
# filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
# callbacks_list = [checkpoint]  , callbacks=callbacks_list
model.fit(network_input, network_output, epochs=epochs, batch_size=batch_size)
# Out:
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/20
# 864/864 [==============================] - 734s 830ms/step - loss: 4.8015
# Epoch 2/20
# 864/864 [==============================] - 722s 835ms/step - loss: 4.4808
# Epoch 3/20
# 864/864 [==============================] - 719s 832ms/step - loss: 4.4582
# Epoch 4/20
# 864/864 [==============================] - 719s 833ms/step - loss: 4.4068
# Epoch 5/20
# 864/864 [==============================] - 719s 832ms/step - loss: 4.2542
# Epoch 6/20
# 864/864 [==============================] - 717s 829ms/step - loss: 4.1266
# Epoch 7/20
# 864/864 [==============================] - 718s 831ms/step - loss: 4.0269
# Epoch 8/20
# 864/864 [==============================] - 718s 831ms/step - loss: 3.9519
# Epoch 9/20
# 864/864 [==============================] - 719s 833ms/step - loss: 3.8944
# Epoch 10/20
# 864/864 [==============================] - 719s 832ms/step - loss: 3.8475
# Epoch 11/20
# 864/864 [==============================] - 718s 831ms/step - loss: 3.8048
# Epoch 12/20
# 864/864 [==============================] - 718s 832ms/step - loss: 3.7611
# Epoch 13/20
# 864/864 [==============================] - 717s 830ms/step - loss: 3.7200
# Epoch 14/20
# 730/864 [========================>.....] - ETA: 1:51 - loss: 3.6755

# %%
# Function to Introduce Randomness in Predictions
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds += 1e-10  # Add a small constant to avoid log(0)
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# Generate Notes from the Model
def generate_notes(model, network_input, note_to_int, int_to_note, temperature=0.5):
    start = np.random.randint(0, len(network_input)-1)
    pattern = network_input[start]
    prediction_output = []

    for note_index in range(500):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(len(note_to_int))
        prediction = model.predict(prediction_input, verbose=0)
        index = sample(prediction[0], temperature)
        result = int_to_note[index]
        prediction_output.append(result)
        pattern = np.append(pattern, index)
        pattern = pattern[1:len(pattern)]

    return prediction_output

# Convert Predictions to MIDI File
def create_midi(prediction_output, output_file='test_output.mid'):
    offset = 0
    output_notes = []
    for pattern in prediction_output:
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)
        offset += 0.5
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp=output_file)

# Generate music
prediction_output = generate_notes(model, network_input, note_to_int, int_to_note)

# Create MIDI file from generated notes
create_midi(prediction_output)
